# %%
print ("a password should comtaim atleast 1 number \n it should be min of 8 charecters \n it should contaion any of the special charecter ")
password = input("Enter a password: ")


if len(password) < 8:
    print("Weak Password")
elif not any(char.isdigit() for char in password):
    print("Password should contain a number")
elif not any(char.isupper() for char in password):
    print("Password should contain an uppercase letter")
elif not any(char in "!@#$%^&*" for char in password):
    print("Password should contain a special character")
else:
    print("Strong Password")
# Out:
# a password should comtaim atleast 1 number
#  it should be min of 8 charecters
#  it should contaion any of the special charecter
# Strong Password
